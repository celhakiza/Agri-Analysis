# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
from tabulate import tabulate
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from scipy.stats import pearsonr

# %%
#reading the excel dataset
df = pd.read_excel('./data/Data on diet_NEW_clean.xlsx',skiprows=2)

# %%
df
# Out:
#     Experiments             Diets replication  15/5/23  23/06  \
# 0   Experiment1  Normal diet (ND)       Rep 1       23      7
# 1   Experiment1  Normal diet (ND)       Rep 2       22     14
# 2   Experiment1  Normal diet (ND)       Rep 3       22     10
# 3   Experiment1  Normal diet (ND)       Rep 4       25     20
# 4   Experiment1                BM       Rep 1       21      5
# 5   Experiment1                BM       Rep 2       21      6
# 6   Experiment1                BM       Rep 3       25     11
# 7   Experiment1                BM       Rep 4       23      6
# 8   Experiment1                RM       Rep 1       22      3
# 9   Experiment1                RM       Rep 2       21     15
# 10  Experiment1                RM       Rep 3       22     12
# 11  Experiment1                RM       Rep 4       24     15
# 12  Experiment1                GL       Rep 1       24     13
# 13  Experiment1                GL       Rep 2       24      9
# 14  Experiment1                GL       Rep 3       25     14
# 15  Experiment1                GL       Rep 4       21     17
# 16  Experiment1               HBW       Rep 1       21     11
# 17  Experiment1               HBW       Rep 2       22      6
# 18  Experiment1               HBW       Rep 3       22     14
# 19  Experiment1               HBW       Rep 4       22     18
# 20  Experiment1               NBW       Rep 1       24     11
# 21  Experiment1               NBW       Rep 2       22     16
# 22  Experiment1               NBW       Rep 3       24      9
# 23  Experiment1               NBW       Rep 4       21      8
# 24  Experiment2  Normal diet (ND)       Rep 1       23      5
# 25  Experiment2  Normal diet (ND)       Rep 2       24     10
# 26  Experiment2  Normal diet (ND)       Rep 3       25      8
# 27  Experiment2  Normal diet (ND)       Rep 4       22      2
# 28  Experiment2                BM       Rep 1       22      5
# 29  Experiment2                BM       Rep 2       23     11
# 30  Experiment2                BM       Rep 3       21     11
# 31  Experiment2                BM       Rep 4       20     12
# 32  Experiment2                RM       Rep 1       24      1
# 33  Experiment2                RM       Rep 2       25      8
# 34  Experiment2                RM       Rep 3       23      9
# 35  Experiment2                RM       Rep 4       23      1
# 36  Experiment2                GL       Rep 1       22     12
# 37  Experiment2                GL       Rep 2       24     10
# 38  Experiment2                GL       Rep 3       24     11
# 39  Experiment2                GL       Rep 4       24     18
# 40  Experiment2               HBW       Rep 1       22     16
# 41  Experiment2               HBW       Rep 2       25     25
# 42  Experiment2               HBW       Rep 3       20     17
# 43  Experiment2               HBW       Rep 4       24     14
# 44  Experiment2               NBW       Rep 1       25     18
# 45  Experiment2               NBW       Rep 2       20     10
# 46  Experiment2               NBW       Rep 3       23     14
# 47  Experiment2               NBW       Rep 4       24      9
#
#     2023-07-03 00:00:00  2024-07-07 00:00:00  2024-07-13 00:00:00  \
# 0                     1                    0                    1
# 1                     0                    1                    0
# 2                     0                    0                    0
# 3                     0                    1                    0
# 4                     3                    2                    0
# 5                     7                    3                    2
# 6                     8                    1                    0
# 7                     8                    6                    1
# 8                     0                    0                    0
# 9                     5                    4                    0
# 10                   13                    7                    1
# 11                    3                    1                    0
# 12                   10                    3                    0
# 13                   11                    2                    0
# 14                    0                    0                    0
# 15                    1                    1                    0
# 16                    0                    0                    0
# 17                    0                    0                    0
# 18                    0                    0                    0
# 19                    1                    0                    0
# 20                    2                    0                    0
# 21                    3                    2                    0
# 22                    1                    0                    0
# 23                    3                    0                    0
# 24                    3                    1                    0
# 25                    0                    0                    0
# 26                    0                    1                    0
# 27                    4                    0                    0
# 28                    3                    0                    0
# 29                   10                    9                    7
# 30                    7                    5                    1
# 31                    7                    3                    0
# 32                    1                    0                    0
# 33                   14                    4                    0
# 34                    4                    3                    0
# 35                    0                    0                    0
# 36                    9                    4                    0
# 37                   18                    3                    0
# 38                    6                    1                    1
# 39                    4                    0                    0
# 40                    0                    0                    0
# 41                    2                    1                    0
# 42                    1                    1                    0
# 43                    0                    0                    0
# 44                    2                    1                    0
# 45                    2                    0                    0
# 46                    2                    1                    0
# 47                    0                    4                    0
#
#     2024-07-19 00:00:00  number_larvae  ...  23/06.2  2023-07-03 00:00:00.2  \
# 0                     0              9  ...      0.0                      0
# 1                     0             15  ...      0.0                      0
# 2                     0             10  ...      0.0                      0
# 3                     0             21  ...      0.0                      0
# 4                     0             10  ...      0.0                      0
# 5                     1             19  ...      0.0                      0
# 6                     0             20  ...      0.0                      0
# 7                     0             21  ...      0.0                      0
# 8                     0              3  ...      0.0                      0
# 9                     0             24  ...      0.0                      0
# 10                    0             33  ...      0.0                      0
# 11                    0             19  ...      0.0                      1
# 12                    0             26  ...      0.0                      0
# 13                    0             22  ...      0.0                      0
# 14                    0             14  ...      0.0                      6
# 15                    0             19  ...      0.0                      2
# 16                    0             11  ...      0.0                      0
# 17                    0              6  ...      0.0                      0
# 18                    0             14  ...      0.0                      0
# 19                    0             19  ...      0.0                      0
# 20                    0             13  ...      0.0                      0
# 21                    0             21  ...      0.0                      0
# 22                    0             10  ...      0.0                      0
# 23                    0             11  ...      0.0                      0
# 24                    0              9  ...      0.0                      0
# 25                    0             10  ...      0.0                      0
# 26                    0              9  ...      0.0                      0
# 27                    0              6  ...      0.0                      0
# 28                    0              8  ...      0.0                      0
# 29                    0             37  ...      0.0                      0
# 30                    0             24  ...      0.0                      0
# 31                    0             22  ...      0.0                      0
# 32                    0              2  ...      0.0                      0
# 33                    0             26  ...      0.0                      0
# 34                    0             16  ...      0.0                      0
# 35                    0              1  ...      0.0                      0
# 36                    0             25  ...      0.0                      0
# 37                    0             31  ...      0.0                      0
# 38                    0             19  ...      0.0                      0
# 39                    0             22  ...      NaN                      1
# 40                    0             16  ...      0.0                      0
# 41                    0             28  ...      0.0                      0
# 42                    0             19  ...      0.0                      0
# 43                    0             14  ...      0.0                      0
# 44                    0             21  ...      0.0                      1
# 45                    0             12  ...      0.0                      0
# 46                    0             17  ...      0.0                      0
# 47                    0             13  ...      0.0                      0
#
#     2024-07-07 00:00:00.2  2024-07-13 00:00:00.2  2024-07-19 00:00:00.2  \
# 0                       0                      0                      7
# 1                       5                     10                      1
# 2                       2                      4                      2
# 3                       5                      2                      2
# 4                       0                      1                     11
# 5                       0                      1                      4
# 6                       0                      4                      1
# 7                       0                      0                      3
# 8                       0                      0                      3
# 9                       0                      1                     10
# 10                      0                      3                      3
# 11                      6                      4                      4
# 12                      1                      3                      1
# 37                       NaN
# 38                       NaN
# 39                       NaN
# 40                     274.0
# 41                       NaN
# 42                       NaN
# 43                       NaN
# 44                     542.0
# 45                       NaN
# 46                       NaN
# 47                       NaN
#
# [48 rows x 38 columns]

# %%
df.columns
# Out:
# Index([                  'Experiments',                         'Diets',
#                          'replication',                       '15/5/23',
#                                '23/06',             2023-07-03 00:00:00,
#                    2024-07-07 00:00:00,             2024-07-13 00:00:00,
#                    2024-07-19 00:00:00,                 'number_larvae',
#                        'nbr_10_larvae',                       '23/06.1',
#                '2023-07-03 00:00:00.1',         '2024-07-07 00:00:00.1',
#                '2024-07-13 00:00:00.1',         '2024-07-19 00:00:00.1',
#        'avg_weight_repl_per_10_larvae',             2023-07-07 00:00:00,
#                          'Unnamed: 18',                   'Unnamed: 19',
#                          'Unnamed: 20',                   'Unnamed: 21',
#                           '13/07/2023',                   'Unnamed: 23',
#                          'Unnamed: 24',                   'Unnamed: 25',
#                          'Unnamed: 26',    'avg_length_per_replication',
#                              '23/06.2',         '2023-07-03 00:00:00.2',
#                '2024-07-07 00:00:00.2',         '2024-07-13 00:00:00.2',
#                '2024-07-19 00:00:00.2',             2024-07-27 00:00:00,
#                    2024-08-04 00:00:00,                       '23/06.3',
#                    2024-07-03 00:00:00,      'avg_nbr_eggs_per_4_moths'],
#       dtype='object')

# %% [markdown]
# ### Diet efficients
# to measure Diet efficient, we used number of larvae and the multiplication of larvae in our dataset
#
# #### 1. Number of larvae produced

# %%
#number of larvae
df_eff = df.groupby('Diets')['number_larvae'].sum().reset_index()
df_eff
# Out:
#               Diets  number_larvae
# 0                BM            161
# 1                GL            178
# 2               HBW            127
# 3               NBW            118
# 4  Normal diet (ND)             89
# 5                RM            124

# %%
#bar chart displaying the results
fig = plt.figure(figsize=(12,5))
bars = plt.bar(df_eff['Diets'], df_eff['number_larvae'],color='skyblue')
plt.xlabel('Diets')
plt.ylabel('number_larvae')
plt.title('number of larvaes produced per each diet type')

# Annotate bars with the percentage values
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2.0,  # x coordinate of the text
        height,  # y coordinate of the text
        f'{height:.0f}',  # text
        ha='center',  # horizontal alignment
        va='bottom'  # vertical alignment
    )
plt.savefig('diets.png')
plt.show()

# %% [markdown]
# **Perform Analysis of Variance**

# %%
groups = df.groupby('Diets')['number_larvae'].apply(list)

# Perform ANOVA
f_stat, p_value = stats.f_oneway(*groups)
print('F-statistic:', f_stat)
print('p-value:', p_value)
# Out:
# F-statistic: 2.248324125230203
# p-value: 0.06703690928150113

# %% [markdown]
# #### 2. Multiplication of larvae

# %%
df_multiplication = df.groupby('Diets')['avg_nbr_eggs_per_4_moths'].mean().reset_index()

# %%
df_multiplication
# Out:
#               Diets  avg_nbr_eggs_per_4_moths
# 0                BM                   1775.25
# 1                GL                    724.25
# 2               HBW                    914.75
# 3               NBW                    403.50
# 4  Normal diet (ND)                   1190.00
# 5                RM                   1897.75

# %%
groups1 = df.groupby('Diets')['avg_nbr_eggs_per_4_moths'].apply(list)

# Perform ANOVA
f_stat, p_value = stats.f_oneway(*groups1)
print('F-statistic:', f_stat)
print('p-value:', p_value)
# Out:
# F-statistic: nan
# p-value: nan
